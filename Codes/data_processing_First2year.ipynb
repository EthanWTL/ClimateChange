# %%
import numpy as np
import pandas as pd
from numpy.ma.core import ceil
from scipy.spatial import distance #distance calculation
from sklearn.preprocessing import MinMaxScaler #normalisation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors
from sklearn.preprocessing import StandardScaler
import os

# %%
df = pd.read_csv('../First2YearModelData/year2_xy.csv',index_col=0)
df.reset_index()
# Out:
#        index         0         1         2         3         4         5  \
# 0          0  0.075077  0.069538  0.064615  0.060308  0.055385  0.051077
# 1          1  0.063385  0.057846  0.052308  0.047385  0.043077  0.038154
# 2          2  0.049231  0.043692  0.038154  0.032615  0.027692  0.023385
# 3          3  0.032615  0.026462  0.020923  0.015385  0.010462  0.006154
# 4          4  0.015385  0.009231  0.003692  0.000000  0.000000  0.000000
# ...      ...       ...       ...       ...       ...       ...       ...
# 11110   2425  0.494154  0.507077  0.518769  0.529231  0.538462  0.546462
# 11111   2426  0.490462  0.503385  0.514462  0.525538  0.534154  0.542154
# 11112   2427  0.485538  0.497846  0.508923  0.520000  0.529231  0.537231
# 11113   2428  0.479385  0.491692  0.502769  0.513231  0.522462  0.531077
# 11114   2429  0.472615  0.484923  0.495385  0.505846  0.515077  0.523692
#
#               6         7         8         9        10        11        12  \
# ...

# %% [markdown]
# # prepare the data

# %% [markdown]
# # CL 0-2684

# %%
path="../First2YearModelData/CL"
data = np.empty(shape=(1,225))
counter = 0
for filename in os.listdir(path):
    counter+=1
    f = os.path.join(path,filename)
    newdata = pd.read_csv(f, header = None).iloc[:,:15].values.reshape((1,-1))
    data = np.concatenate((data,newdata))

print(data.shape)

x = []
for i in range(0,2679,15):
    x.append(int(df.iloc[i]['15']))

y = []
for i in range(0,2679,15):
    y.append(int(df.iloc[i]['16']))
    
x_read = np.array(x)
x_read = x_read.reshape((1,-1))

y_read = np.array(y)
y_read = y_read.reshape((1,-1))

data_final = np.concatenate((data, x_read.T,y_read.T), axis=1)
data_final_frame = pd.DataFrame(data_final)
data_final_frame.to_csv('cl2year_xy.csv')
print(data_final_frame.shape)
print(counter)
data_final_frame
# Out:
# (179, 225)
# (179, 227)
# 178
#           0         1         2         3         4         5         6    \
# 0    0.329231  0.328000  0.326154  0.323692  0.321231  0.318769  0.316923
# 1    0.139692  0.139077  0.137846  0.137231  0.137231  0.137231  0.137846
# 2    0.475692  0.473846  0.471385  0.468923  0.465846  0.462769  0.460308
# 3    0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# 4    0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# ..        ...       ...       ...       ...       ...       ...       ...
# 174  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 175  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 176  0.036308  0.035077  0.033846  0.033846  0.033846  0.034462  0.035692
# 177  0.040615  0.039385  0.038769  0.038154  0.038154  0.038769  0.039385
# 178  0.161231  0.158769  0.156308  0.154462  0.152615  0.150154  0.147692
#
# ...

# %% [markdown]
# # COH 2685-5114 162 rows

# %%
path="../First2YearModelData/COH"
data = np.empty(shape=(1,225))
for filename in os.listdir(path):
    f = os.path.join(path,filename)
    newdata = pd.read_csv(f, header = None).iloc[:,:15].values.reshape((1,-1))
    data = np.concatenate((data,newdata))

x = []
for i in range(2685,5114,15):
    x.append(int(df.iloc[i]['15']))

y = []
for i in range(2685,5114,15):
    y.append(int(df.iloc[i]['16']))
    
x_read = np.array(x)
x_read = x_read.reshape((1,-1))

y_read = np.array(y)
y_read = y_read.reshape((1,-1))

data_final = np.concatenate((data, x_read.T,y_read.T), axis=1)
data_final_frame = pd.DataFrame(data_final)
data_final_frame.to_csv('coh2year_xy.csv')
data_final_frame
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.476923  0.472615  0.468923  0.466462  0.464000  0.462769  0.462769
# 1    0.390154  0.395077  0.400615  0.406154  0.411077  0.414769  0.419692
# 2    0.534154  0.541538  0.549538  0.558154  0.565538  0.572308  0.577846
# 3    0.517538  0.518769  0.520615  0.521846  0.524308  0.526154  0.528000
# 4    0.550769  0.552615  0.553846  0.553846  0.553846  0.552000  0.550154
# ..        ...       ...       ...       ...       ...       ...       ...
# 157  0.828923  0.826462  0.823385  0.819692  0.815385  0.811077  0.806769
# 158  0.592000  0.609231  0.625846  0.640615  0.655385  0.667692  0.678154
# 159  0.646154  0.648000  0.649846  0.651692  0.652308  0.652923  0.653538
# 160  0.437538  0.448615  0.457846  0.467077  0.474462  0.480000  0.488000
# 161  0.462154  0.472000  0.480615  0.488615  0.494154  0.497846  0.502154
#
#           7         8         9    ...       217       218       219  \
# ...

# %% [markdown]
# # COL 5115-10034  328 row

# %%
path="../First2YearModelData/COL"
data = np.empty(shape=(1,225))
for filename in os.listdir(path):
    f = os.path.join(path,filename)
    newdata = pd.read_csv(f, header = None).iloc[:,:15].values.reshape((1,-1))
    data = np.concatenate((data,newdata))

x = []
for i in range(5115,10034,15):
    x.append(int(df.iloc[i]['15']))

y = []
for i in range(5115,10034,15):
    y.append(int(df.iloc[i]['16']))
    
x_read = np.array(x)
x_read = x_read.reshape((1,-1))

y_read = np.array(y)
y_read = y_read.reshape((1,-1))

data_final = np.concatenate((data, x_read.T,y_read.T), axis=1)
data_final_frame = pd.DataFrame(data_final)
data_final_frame.to_csv('col2year_xy.csv')
data_final_frame
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.712000  0.723077  0.732923  0.740923  0.748308  0.753846  0.758769
# 1    0.550769  0.541538  0.531077  0.519385  0.508308  0.496615  0.486154
# 2    0.415385  0.419692  0.423385  0.427077  0.430154  0.432000  0.433231
# 3    0.574154  0.561231  0.549538  0.539077  0.529846  0.521846  0.515077
# 4    0.596308  0.579692  0.562462  0.547692  0.534769  0.523077  0.514462
# ..        ...       ...       ...       ...       ...       ...       ...
# 323  0.684923  0.686154  0.688615  0.691077  0.691692  0.690462  0.688615
# 324  0.633231  0.632000  0.633231  0.633846  0.633846  0.633231  0.632000
# 325  0.679385  0.680000  0.680000  0.680000  0.678769  0.678154  0.676923
# 326  0.499077  0.486154  0.473846  0.463385  0.454154  0.446154  0.440615
# 327  0.571077  0.555077  0.540308  0.526769  0.514462  0.503385  0.493538
#
#           7         8         9    ...       217       218       219  \
# ...

# %% [markdown]
# # NROI

# %%
path="../First2YearModelData/NROI"
data = np.empty(shape=(1,225))
for filename in os.listdir(path):
    f = os.path.join(path,filename)
    newdata = pd.read_csv(f, header = None).iloc[:,:15].values.reshape((1,-1))
    data = np.concatenate((data,newdata))

x = []
for i in range(10035,11114,15):
    x.append(int(df.iloc[i]['15']))

y = []
for i in range(10035,11114,15):
    y.append(int(df.iloc[i]['16']))
    
x_read = np.array(x)
x_read = x_read.reshape((1,-1))

y_read = np.array(y)
y_read = y_read.reshape((1,-1))

data_final = np.concatenate((data, x_read.T,y_read.T), axis=1)
data_final_frame = pd.DataFrame(data_final)
data_final_frame.to_csv('nroi2year_xy.csv')
data_final_frame
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.679385  0.680000  0.680000  0.680000  0.678769  0.678154  0.676923
# 1   0.906462  0.909538  0.912000  0.915077  0.919385  0.922462  0.924923
# 2   0.887385  0.891692  0.897231  0.900923  0.904000  0.907692  0.909538
# 3   0.967385  0.966769  0.964308  0.959385  0.953231  0.947077  0.941538
# 4   0.970462  0.970462  0.969846  0.966769  0.961846  0.955692  0.948308
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.844923  0.857231  0.872615  0.886154  0.890462  0.892308  0.890462
# 68  0.912615  0.915692  0.923692  0.929846  0.932308  0.935385  0.936615
# 69  0.931077  0.933538  0.931692  0.931692  0.931077  0.929231  0.928615
# 70  0.868923  0.875077  0.880000  0.883692  0.884923  0.884923  0.883692
# 71  0.856000  0.864000  0.874462  0.876923  0.873846  0.864000  0.868923
#
#          7         8         9    ...       217       218       219       220  \
# ...

# %%
import pandas as pd

# %%
cl = pd.read_csv('cl2year_xy.csv',index_col = 0)
cl

# %%
col = pd.read_csv('col2year_xy.csv',index_col = 0)
col
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.712000  0.723077  0.732923  0.740923  0.748308  0.753846  0.758769
# 1    0.550769  0.541538  0.531077  0.519385  0.508308  0.496615  0.486154
# 2    0.415385  0.419692  0.423385  0.427077  0.430154  0.432000  0.433231
# 3    0.574154  0.561231  0.549538  0.539077  0.529846  0.521846  0.515077
# 4    0.596308  0.579692  0.562462  0.547692  0.534769  0.523077  0.514462
# ..        ...       ...       ...       ...       ...       ...       ...
# 323  0.684923  0.686154  0.688615  0.691077  0.691692  0.690462  0.688615
# 324  0.633231  0.632000  0.633231  0.633846  0.633846  0.633231  0.632000
# 325  0.679385  0.680000  0.680000  0.680000  0.678769  0.678154  0.676923
# 326  0.499077  0.486154  0.473846  0.463385  0.454154  0.446154  0.440615
# 327  0.571077  0.555077  0.540308  0.526769  0.514462  0.503385  0.493538
#
#             7         8         9  ...       217       218       219  \
# ...

# %%
coh = pd.read_csv('coh2year_xy.csv',index_col = 0)
coh
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.476923  0.472615  0.468923  0.466462  0.464000  0.462769  0.462769
# 1    0.390154  0.395077  0.400615  0.406154  0.411077  0.414769  0.419692
# 2    0.534154  0.541538  0.549538  0.558154  0.565538  0.572308  0.577846
# 3    0.517538  0.518769  0.520615  0.521846  0.524308  0.526154  0.528000
# 4    0.550769  0.552615  0.553846  0.553846  0.553846  0.552000  0.550154
# ..        ...       ...       ...       ...       ...       ...       ...
# 157  0.828923  0.826462  0.823385  0.819692  0.815385  0.811077  0.806769
# 158  0.592000  0.609231  0.625846  0.640615  0.655385  0.667692  0.678154
# 159  0.646154  0.648000  0.649846  0.651692  0.652308  0.652923  0.653538
# 160  0.437538  0.448615  0.457846  0.467077  0.474462  0.480000  0.488000
# 161  0.462154  0.472000  0.480615  0.488615  0.494154  0.497846  0.502154
#
#             7         8         9  ...       217       218       219  \
# ...

# %%
nroi = pd.read_csv('nroi2year_xy.csv',index_col = 0)
nroi
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.679385  0.680000  0.680000  0.680000  0.678769  0.678154  0.676923
# 1   0.906462  0.909538  0.912000  0.915077  0.919385  0.922462  0.924923
# 2   0.887385  0.891692  0.897231  0.900923  0.904000  0.907692  0.909538
# 3   0.967385  0.966769  0.964308  0.959385  0.953231  0.947077  0.941538
# 4   0.970462  0.970462  0.969846  0.966769  0.961846  0.955692  0.948308
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.844923  0.857231  0.872615  0.886154  0.890462  0.892308  0.890462
# 68  0.912615  0.915692  0.923692  0.929846  0.932308  0.935385  0.936615
# 69  0.931077  0.933538  0.931692  0.931692  0.931077  0.929231  0.928615
# 70  0.868923  0.875077  0.880000  0.883692  0.884923  0.884923  0.883692
# 71  0.856000  0.864000  0.874462  0.876923  0.873846  0.864000  0.868923
#
#            7         8         9  ...       217       218       219       220  \
# ...

# %%
cl['label'] = 'CL'

# %%
col['label'] = 'COL'
coh['label'] = 'COH'
nroi['label'] = 'NROI'

# %%
cl
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.329231  0.328000  0.326154  0.323692  0.321231  0.318769  0.316923
# 1    0.139692  0.139077  0.137846  0.137231  0.137231  0.137231  0.137846
# 2    0.475692  0.473846  0.471385  0.468923  0.465846  0.462769  0.460308
# 3    0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# 4    0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# ..        ...       ...       ...       ...       ...       ...       ...
# 174  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 175  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 176  0.036308  0.035077  0.033846  0.033846  0.033846  0.034462  0.035692
# 177  0.040615  0.039385  0.038769  0.038154  0.038154  0.038769  0.039385
# 178  0.161231  0.158769  0.156308  0.154462  0.152615  0.150154  0.147692
#
#             7         8         9  ...       218       219       220  \
# ...

# %%
data = pd.concat([cl,coh,col,nroi])

# %%
data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.329231  0.328000  0.326154  0.323692  0.321231  0.318769  0.316923
# 1   0.139692  0.139077  0.137846  0.137231  0.137231  0.137231  0.137846
# 2   0.475692  0.473846  0.471385  0.468923  0.465846  0.462769  0.460308
# 3   0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# 4   0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.844923  0.857231  0.872615  0.886154  0.890462  0.892308  0.890462
# 68  0.912615  0.915692  0.923692  0.929846  0.932308  0.935385  0.936615
# 69  0.931077  0.933538  0.931692  0.931692  0.931077  0.929231  0.928615
# 70  0.868923  0.875077  0.880000  0.883692  0.884923  0.884923  0.883692
# 71  0.856000  0.864000  0.874462  0.876923  0.873846  0.864000  0.868923
#
#            7         8         9  ...       218       219       220       221  \
# ...

# %%
data.to_csv('year2data.csv')

# %%
data = pd.read_csv()
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.329231  0.328000  0.326154  0.323692  0.321231  0.318769  0.316923
# 1   0.139692  0.139077  0.137846  0.137231  0.137231  0.137231  0.137846
# 2   0.475692  0.473846  0.471385  0.468923  0.465846  0.462769  0.460308
# 3   0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# 4   0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# ..       ...       ...       ...       ...       ...       ...       ...
# 67  0.844923  0.857231  0.872615  0.886154  0.890462  0.892308  0.890462
# 68  0.912615  0.915692  0.923692  0.929846  0.932308  0.935385  0.936615
# 69  0.931077  0.933538  0.931692  0.931692  0.931077  0.929231  0.928615
# 70  0.868923  0.875077  0.880000  0.883692  0.884923  0.884923  0.883692
# 71  0.856000  0.864000  0.874462  0.876923  0.873846  0.864000  0.868923
#
#            7         8         9  ...       218       219       220       221  \
# ...
